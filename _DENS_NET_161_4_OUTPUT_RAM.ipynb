# %%
import h5py
import re
import hickle as hkl
import torch
import torch.nn as nn
from torch.legacy.nn import Reshape
import graphviz
import torch.nn.functional as F
from torch.autograd import Variable
#from visualize import make_dot
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
import torch.utils.data as utils
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import imresize, imread, imshow
import time
import logging
from math import log,sqrt

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
dense161 = models.densenet161(pretrained=True)
#dense161

# %%
dense161

# %%
def InitializeWeights(mod):
    for m in mod.modules():
        if isinstance(m,nn.Conv2d):
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            #print m.weight.size(), m.out_channels, m.in_channels
            m.weight.data.normal_(0,sqrt(2./n))
        elif isinstance(m, nn.BatchNorm2d):
            m.weight.data.fill_(1)
            m.bias.data.zero_()
        elif isinstance(m, nn.Linear):
            m.weight.data.fill_(1)
            m.bias.data.zero_()
    return mod

# %%
conv1 = nn.Sequential(nn.BatchNorm2d(2208),nn.ReLU(),nn.Conv2d(2208,1024,1))
conv1 = InitializeWeights(conv1)
conv2 = nn.Sequential(nn.BatchNorm2d(1024),nn.ReLU(),nn.Conv2d(1024,128,5))
conv2 = InitializeWeights(conv2)
conv3 = nn.Sequential(nn.BatchNorm2d(128),nn.ReLU(),nn.Conv2d(128,16,(1,5)))
conv3 = InitializeWeights(conv3)
conv4 = nn.Sequential(nn.BatchNorm2d(16),nn.ReLU(),nn.Conv2d(16,1,1))
conv4 = InitializeWeights(conv4)


# fc1 = nn.Sequential(nn.BatchNorm2d(16),nn.ReLU(),nn.Linear(96, 2))
# fc1 = InitializeWeights(fc1)

# %%
#net = net.cpu()
class MyModel4(nn.Module):
    def __init__(self, pretrained_model):
        super(MyModel4, self).__init__()
        self.pretrained_model = nn.Sequential(*list(dense161.children())[:-1])
        self.conv1 = conv1
        self.conv2 = conv2
        self.conv3 = conv3
        self.conv4 = conv4
        #self.fc1 = fc1
        
    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features
        
    def forward(self, x):
        x = self.pretrained_model(x) 
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        
        x = x.view(-1,2)
        
#         x = x.view(-1, self.num_flat_features(x))
#         x=F.relu(self.fc1(x))
        
        #x = self.conv0(x)
        #x = self.bnorm(x)
       # x = self.unpool_conv(x,self.conv1,self.unpool1)
       # x = self.unpool_conv(x,self.conv2,self.unpool1)
        #x = self.unpool_conv(x,self.conv3,self.unpool1)
       # #x = self.unpool_conv(x,self.conv4,self.unpool2)
       # #x = self.unpool2(x)
        #x = self.conv4(x)
        #x = x.view(-1,60,80)
        
        return x
#print(net)

# %%
#net = net.cpu()
net = MyModel4(dense161)

# %%
input=Variable(torch.randn(5,3,180,320))
output=net(input)
print(output.size())
# Out:
# torch.Size([5, 2])

# %%
params = list(net.parameters())
print(len(params))
print(params[0].size())  # conv1's .weight
# Out:
# 498
# torch.Size([96, 3, 7, 7])

# %%
sum1 = 0
        
print("Number of layers ---> ",len(list(net.parameters())))
for params in net.parameters():
    if params.requires_grad == True:
        sum1 += params.numel()
    
print("Total number of parameters ---> ",sum1)
# Out:
# Number of layers --->  498
# Total number of parameters --->  32027969

# %%
input = Variable(torch.randn(5, 3, 180, 320))
out = net(input)
print(out)
# Out:
# Variable containing:
#  6.4645  2.6952
# -3.3818  1.5954
# -5.7000 -8.5696
#  2.6647  4.6406
#  0.0125  3.9559
# [torch.FloatTensor of size 5x2]

# %%
file = h5py.File('./DATASET/CODE/NewTrainData.h5')
xtrainT = torch.from_numpy(np.array(file['xtrain'],dtype=np.float32)).float()
ytrainT = torch.from_numpy(np.array(file['ytrain'],dtype=np.float32)).float()
#xtrain = np.array(file['xtrain'],dtype=np.float32)
#ytrain = np.array(file['ytrain'],dtype=np.float32)

# %%
file = h5py.File('./DATASET/CODE/NewTestData.h5')
xtestT = torch.from_numpy(np.array(file['xtest'],dtype=np.float32)).float()
ytestT = torch.from_numpy(np.array(file['ytest'],dtype=np.float32)).float()
#xtest = np.array(file['xtest'],dtype=np.float32)
#ytest = np.array(file['ytest'],dtype=np.float32)

# %%
print(ytestT.size())
# Out:
# torch.Size([1560, 2, 3])

# %%
def batch_rgb_to_bgr(batch):
    #print(batch.size())
    (r, g, b) = torch.chunk(batch, 3, 1)
    #print(r.size())
    batch1 = torch.cat((b, g, r),1)
    #print(batch1.size())
    return batch1

# %%
xtrainT = batch_rgb_to_bgr(xtrainT)
xtestT = batch_rgb_to_bgr(xtestT)
print(xtrainT.size(), xtestT.size())
# Out:
# torch.Size([20100, 3, 180, 320]) torch.Size([1560, 3, 180, 320])

# %%
xtrainT = torch.div(xtrainT,255.0)
xtestT = torch.div(xtestT,255.0)

# %%
print(torch.min(xtrainT), torch.max(xtrainT), torch.min(xtestT), torch.max(xtestT))
# Out:
# 0.0 1.0 0.0 1.0

# %%
print(xtrainT.size(), ytrainT.size(), xtestT.size(), ytestT.size())
# Out:
# torch.Size([20100, 3, 180, 320]) torch.Size([20100, 2, 3]) torch.Size([1560, 3, 180, 320]) torch.Size([1560, 2, 3])

# %%
class Normalize(object):
    """
    Normalize an tensor image with mean and standard deviation.
    Given mean: (R, G, B) and std: (R, G, B),
    will normalize each channel of the torch.*Tensor, i.e.
    channel = (channel - mean) / std
    Args:
        mean (sequence): Sequence of means for R, G, B channels respecitvely.
        std (sequence): Sequence of standard deviations for R, G, B channels
            respecitvely.
    """

    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        # TODO: make efficient
        for t, m, s in zip(tensor, self.mean, self.std):
            t.sub_(m).div_(s)
        return tensor

# %%
mn = [0.406,0.456,0.485]
sd = [0.225,0.224,0.229]
norm = Normalize(mn,sd)
xtrainT = norm(xtrainT)
xtestT = norm(xtestT)

# %%
print(torch.min(xtrainT), torch.max(xtrainT), torch.min(xtestT), torch.max(xtestT))
# Out:
# -2.1179039478302 2.640000104904175 -2.1007792949676514 2.640000104904175

# %%
##def train(model, loss, optimizer, x_val, y_val, validPixel, batch_sz):
def train(model, loss, optimizer, x_val, y_val):
    x = Variable(x_val,requires_grad = False).cuda()
    y = Variable(y_val,requires_grad = False).cuda()
    
    optimizer.zero_grad()
    
    fx = model.forward(x)
    
    #print fx.data[0][0][64][87]
    #fx = model5.forward(Variable(xtest2[start:end], volatile=True).cuda())
    ##output = loss.forward(fx,y,validPixel,batch_sz)
    output = loss.forward(fx,y)
    #output = loss(fx, y)
    output.backward()
    
    optimizer.step()
    
    return output.data[0]

# %%
#custom loss function.... this will be reverse Huber...

class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss, self).__init__()
        
    def forward(self,inp, tar):
        #target is the ground truth value...
        #k = torch.mean(inp[:,0])
        '''
        if (k >= 1.48 and k <= 1.65):
            diff = torch.abs(tar[:,1]-inp[:,1])
            loss = torch.mean(torch.pow(diff,2))
        else:
        '''
        diff = torch.abs(tar[:,0]-inp[:,0]) #*(180/np.pi)
        loss = torch.mean(torch.pow(diff,2))
        #print(loss)
        return loss
        '''
        c1 = c.data[0] 
        temp = diff > c1
        check1 = torch.prod(temp)
        
        if check1 == 0:
            lossval = torch.mean(diff)
        else:
            temp4 = torch.pow(diff,2)
            d = torch.pow(c,2)
            temp4 = temp4.add(d.expand_as(temp4))
            lossval = torch.mean(temp4/(2*c))
        return lossval
        '''

# %%
#custom loss function.... this will be reverse Huber...

class EuclideanLoss(nn.Module):
    def __init__(self):
        super(EuclideanLoss, self).__init__()
        
    def forward(self,inp, tar):
        #target is the ground truth value...
        #k = torch.mean(inp[:,0])
        '''
        if (k >= 1.48 and k <= 1.65):
            diff = torch.abs(tar[:,1]-inp[:,1])
            loss = torch.mean(torch.pow(diff,2))
        else:
        '''
        #diff = torch.abs(tar[:,0]-inp[:,0]) #*(180/np.pi)
        #loss = torch.mean(torch.pow(diff,2))
        
        
        
        #print(tar.size(),inp.size())
        diff1 = ((tar[:,0]-inp[:,0])/320)**2+((tar[:,1]-inp[:,1])/180)**2
        diff2 = ((tar[:,2]-inp[:,2])/320)**2+((tar[:,3]-inp[:,3])/180)**2
        diff=diff1+diff2
        loss = torch.mean(diff)
        
        
        
        #print(loss)
        return loss
        '''
        c1 = c.data[0] 
        temp = diff > c1
        check1 = torch.prod(temp)
        
        if check1 == 0:
            lossval = torch.mean(diff)
        else:
            temp4 = torch.pow(diff,2)
            d = torch.pow(c,2)
            temp4 = temp4.add(d.expand_as(temp4))
            lossval = torch.mean(temp4/(2*c))
        return lossval
        '''

# %%
#alpha = torch.FloatTensor(ytrainT[5,0])
alpha = ytrainT[5,0]
#print(alpha.shape)
xt = torch.FloatTensor([np.cos(alpha),np.sin(alpha)])
print(ytrainT[5,0],xt.size())
# Out:
# 1.5909278392791748 torch.Size([2])

# %%
alpha = ytrainT[5:10,0]
print(torch.cos(alpha[0:1]-alpha[1:2]))
xt = torch.stack([torch.cos(alpha[0:1]),torch.sin(alpha[0:1])])
xp = torch.stack([torch.cos(alpha[1:2]),torch.sin(alpha[1:2])])
print(xt[0],xt[1])
#print(los)
# Out:
#  0.9992
# [torch.FloatTensor of size 1]
#
#
# 1.00000e-02 *
#  -2.0130
# [torch.FloatTensor of size 1]
#
#  0.9998
# [torch.FloatTensor of size 1]

# %%
print(torch.acos(1))

# %%
class CosineLoss(nn.Module):
    def __init__(self):
        super(CosineLoss, self).__init__()
        
    def forward(self,inp, tar):   
        print("LOSSS")
        xt = tar[:,2]-tar[:,0]
        yt = tar[:,3]-tar[:,1]
        xp = inp[:,0]
        yp = inp[:,1]      
        N1 = torch.sqrt(torch.pow(xt,2)+torch.pow(yt,2))
        N2 = torch.sqrt(torch.pow(xp,2)+torch.pow(yp,2))
        N = N1*N2
        sim = (xt*xp + yt*yp)/N
        print(torch.mean(sim))
        dist = torch.acos(sim)/np.pi
        #print(dist.size())
        #loss = 1 - torch.mean(sim)
        #print(loss)
        loss = torch.mean(dist)
        #loss1 = 1 - torch.mean(sim)
        #print("herrerererre")
        #print(loss, loss1)
        print(loss)
        return loss
        
#         alpha_t = tar[:,0]
#         alpha_p = inp[:,0]
#         #xt = torch.stack([torch.cos(alpha_t),torch.sin(alpha_t)])
#         #xp = torch.stack([torch.cos(alpha_p),torch.sin(alpha_p)])
#         #cos = nn.CosineSimilarity(dim=1, eps=1e-6)
#         #loss = cos(xt, xp)
#         #return loss
#         loss = Variable(torch.FloatTensor(batch_sz).zero_(), requires_grad=False).cuda()
#         for i in range(batch_sz):          
#             loss[i] = torch.cos(alpha_t[i:i+1]-alpha_p[i:i+1])
            
#         lossval = 1.0-torch.mean(loss)    
        #print(lossval)
#         return lossval

# %%
#MUST UNCOMMENT BELOW LINE...
    
net = net.cuda()

#loading the model after the weights of epoch50.. to check what loss the model gives if lr is taken as 0.0001
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

#criterion = RMSELoss()
#criterion = BerhuLoss()
#criterion = EuclideanLoss()
#criterion = nn.MSELoss()
#criterion = EuclideanLoss()
#criterion = torch.nn.MSELoss(size_average=False)
#criterion = CustomLoss()
criterion = CosineLoss()
criterion.cuda()

currepochloss = float('Inf')
#epochs, n_examples, i, batch_size, flag = 1,5900, 0, 5, 0
epochs, n_examples, i, batch_size, flag = 1, 20100, 0, 30, 0


while i != epochs:
    since = time.time()
    cost, batchloss = 0.0, 0.0
    num_batches = n_examples//batch_size
    #print num_batches    #indices = np.random.permutation(5600)
    #indices = np.random.permutation(3524)
    
    #indices = np.random.permutation(5900)
    indices = np.random.permutation(n_examples)
    samplesUnprocessed = np.size(indices)
    
    #batchwise training starts here...
    for k in range(num_batches):
        since1 = time.time()
       # print("bacth number:"+str(k))
        xtrain3 = torch.FloatTensor(batch_size,3,180,320)
        ytrain3 = torch.FloatTensor(batch_size,4)
        ##validPixel = torch.FloatTensor(batch_size,480,640)
        
        for ind in range(batch_size):
            #ind1 = np.random.randint(0,5599)
            ind1 = np.random.randint(0,samplesUnprocessed)
            #ind1 = np.random.randint(0,794)
            #ind1 = np.random.randint(0,794)            
            newxind = indices[ind1]            
            xtrain3[ind] = xtrainT[newxind]
            #ytrain3[ind] = ytrainT[newxind]
            ytrain3[ind,0] = ytrainT[newxind,0,0]
            ytrain3[ind,1] = ytrainT[newxind,0,1]
            ytrain3[ind,2] = ytrainT[newxind,1,0]
            ytrain3[ind,3] = ytrainT[newxind,1,1]        
            ##validPixel[ind] = imgValidTrain2[newxind]
            
            #print ytrain3[ind,0,0,0], ytrain2[newxind,0,0,0]
            indices = np.delete(indices,ind1)
            samplesUnprocessed = samplesUnprocessed - 1
        
        #start, end = k*batch_size, (k+1)*batch_size
        #batchloss = train(model5,criterion, optimizer, xtrain3, ytrain3, validPixel,batch_size)
        batchloss = train(net,criterion, optimizer, xtrain3, ytrain3)
        batch_time = time.time() - since1
        #cost += batchloss
        cost = (cost*k+batchloss)/(k+1)
        #print k,cost
        #print("No. of samples UnProcessed "+str(samplesUnprocessed))
        
    time_elapsed = time.time() - since
    epochloss = cost #/num_batches
    
    if epochloss < currepochloss:
        print('save the weights')
        torch.save(net.state_dict(),"./weights/CosineDistance/CosineDistance_vector_20100_1_epochs.pth")
        flag = 0
        currepochloss = epochloss
    else:
        flag += 1
        
        if flag == 5:
            for p in optimizer.param_groups:
                lr2 = p['lr']
            newlr = lr2/5
            
            if newlr < 1e-15:
                print("Cant decrease further!!")
                newlr = 1e-15
            flag = 0 
            optimizer = optim.SGD(net.parameters(), lr=newlr, momentum=0.9)
            print("Learning rate changed from "+str(lr2)+" to "+str(newlr))
            
        print("Loss "+str(epochloss)+" is bigger than Loss "+str(currepochloss)+" in the prev epoch ")
        
    print('Loss = {:.5f} at epoch {:d} completed in {:.0f}m {:.0f}s'.format(epochloss,(i+1),(time_elapsed//60),(time_elapsed%60)))
    i += 1
# Out:
# LOSSS
# Variable containing:
# 1.00000e-03 *
#   5.7916
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4943
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# 1.00000e-02 *
#   8.9532
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4617
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# 1.00000e-02 *
#   9.8428
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4651
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.2606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3927
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.1852
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4221
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# 1.00000e-02 *
#   7.9316
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4587
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.2454
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3941
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.3075
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3595
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4534
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3170
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.5804
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2653
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4951
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3068
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4638
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3107
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.2414
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4046
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4628
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3235
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.1701
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4276
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4992
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2912
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.3799
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3396
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.2920
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3876
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# 1.00000e-02 *
#   5.7241
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4743
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.6356
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2298
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.2753
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3805
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.6064
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2526
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.2532
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3896
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.5290
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2728
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4185
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.3774
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3401
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.3949
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3313
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.5838
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2602
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.2510
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4043
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4733
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3097
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.3379
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3637
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.5443
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2765
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7566
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1790
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.6102
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2445
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.4474
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3105
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7850
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1760
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7210
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2032
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7342
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1993
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.6962
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2045
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.5981
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2449
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.5913
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2431
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7445
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1877
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7970
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1587
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7259
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1876
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7773
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1724
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7844
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1588
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8918
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1609
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8477
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1296
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7733
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1713
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.6389
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2391
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7401
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1772
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7686
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1794
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7814
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1705
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# LOSSS
# Variable containing:
#  0.8309
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1432
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8278
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1367
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8110
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1560
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8313
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1442
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9255
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1038
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8040
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1616
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1268
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8937
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1166
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8542
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8326
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9377
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.4287
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1459
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7589
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1818
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8676
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1170
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8804
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1144
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8353
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1436
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8594
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1420
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9009
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8943
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1104
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9142
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.7076
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1504
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9124
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1011
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8357
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1306
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1051
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9004
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1130
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8696
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1207
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9213
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.4387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8356
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1484
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8241
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1469
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8111
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1618
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8302
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1317
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8711
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1303
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9113
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.7376
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8541
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1339
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8549
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1292
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9450
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.1922
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9011
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1178
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8997
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1084
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8997
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1063
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8940
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1137
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9310
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1003
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9145
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1024
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9246
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.6406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8678
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1182
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8933
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1151
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9539
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.1376
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8809
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1241
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9320
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.8141
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9327
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.1325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1103
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9023
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9446
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.3849
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9338
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.4240
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# LOSSS
# Variable containing:
#  0.8812
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1283
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7962
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1568
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9202
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.3818
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9111
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.9308
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9416
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.1888
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8864
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1219
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9543
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.9120
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8804
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1115
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9116
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1138
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9268
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.9460
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9336
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.5604
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9280
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.9917
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9510
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.9476
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9164
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.8369
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9326
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.9923
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9251
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.1653
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9254
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.8708
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9531
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.5641
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9559
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9520
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.2814
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8700
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9477
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.6282
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9572
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.6805
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9589
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.4284
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9644
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.0014
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.4883
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9448
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.7794
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.9469
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9434
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.3124
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.7410
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1866
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9042
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1173
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9223
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.0024
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8828
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9749
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.5339
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9687
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.3159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9669
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.0838
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9488
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.7717
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9611
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.8595
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9277
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.2929
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9642
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.1577
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.0846
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9482
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.6284
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9278
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.7608
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9569
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.9892
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1034
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.6072
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9472
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.6452
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9342
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.9090
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9395
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.6823
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9604
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.2154
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# LOSSS
# Variable containing:
#  0.9644
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.9519
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9605
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.7682
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9508
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.0652
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9398
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.9415
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.8736
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.1249
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9510
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.8908
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9234
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.3266
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9370
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.2977
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9796
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.0461
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9243
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.0391
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9371
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.1399
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9629
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.9038
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9528
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.1024
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9648
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.4303
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9793
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   5.0766
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9450
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.7275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9615
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   7.3365
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   8.7826
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9294
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   9.5929
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
#  0.9680
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# 1.00000e-02 *
#   6.2998
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# LOSSS
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# nan
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f9f8ada5752d> in <module>()
#      60         #start, end = k*batch_size, (k+1)*batch_size
#      61         #batchloss = train(model5,criterion, optimizer, xtrain3, ytrain3, validPixel,batch_size)
# ---> 62         batchloss = train(net,criterion, optimizer, xtrain3, ytrain3)
#      63         batch_time = time.time() - since1
#      64         #cost += batchloss
#
# <ipython-input-21-0579ea6891d5> in train(model, loss, optimizer, x_val, y_val)
#      13     output = loss.forward(fx,y)
#      14     #output = loss(fx, y)
# ---> 15     output.backward()
#      16
#      17     optimizer.step()
#
# /home/cvrlab2/anaconda3/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_variables)
#     144                     'or with gradient w.r.t. the variable')
#     145             gradient = self.data.new().resize_as_(self.data).fill_(1)
# --> 146         self._execution_engine.run_backward((self,), (gradient,), retain_variables)
#     147
#     148     def register_hook(self, hook):
#
# KeyboardInterrupt:

# %%
for params in optimizer.param_groups:
    print(params['lr'])
# Out:
# 8.000000000000001e-06

# %%
#net = net.cuda()
#net.load_state_dict(torch.load("./weights/corridor_new_data_bgr_600.pth"))

# %%
#testing of the architecture...
num_batches = 0
#6 evenly divides the test batch size..
test_batch_size = 10
n_examples = 1560
#finalpred = Variable(torch.zeros((n_examples,3,120,160)))
finalpred = Variable(torch.zeros((n_examples,2)))
print("finalpred size is ---> ", finalpred.size())

num_batches = n_examples//test_batch_size
print("num of batches --->", num_batches)
for k in range(num_batches):
    start, end = k*test_batch_size, (k+1)*test_batch_size
    output = net.forward(Variable(xtestT[start:end], volatile=True).cuda())
    finalpred[start:end] = output
# Out:
# finalpred size is --->  torch.Size([1560, 2])
# num of batches ---> 156

# %%
data1 = finalpred.data.numpy()
print(data1.shape)
# Out:
# (1560, 2)

# %%
vectors = finalpred.data
print(ytestT.size(), vectors.size())
angle_target = ytestT[:,:,2][:,0]
print(angle_target.size(),angle_target[0])
angle_pred = np.pi - torch.atan(vectors[:,1]/vectors[:,0])
print(angle_pred.size(),angle_pred[0])
angle_diff = torch.abs(angle_target-angle_pred)
mse_angleRad = torch.mean(torch.pow(angle_diff,2))
mse_angleDeg = mse_angleRad*(180/np.pi)
print("MSE (Radian) = "+str(mse_angle))
print("MSE (Degree) = "+str(mse_angleDeg))
abs_angleRad = torch.mean((angle_diff))
abs_angleDeg = abs_angleRad*(180/np.pi)
print("Absolute Angle (Radian) = "+str(abs_angleRad))
print("Absolute Angle (Degree) = "+str(abs_angleDeg))
# Out:
# torch.Size([1560, 2, 3]) torch.Size([1560, 2])
# torch.Size([1560]) 1.5947643518447876
# torch.Size([1560]) 3.558873414993286
# MSE (Radian) = 2.4987076480770405
# MSE (Degree) = 115.20318497776442
# Absolute Angle (Radian) = 1.2603357813297174
# Absolute Angle (Degree) = 72.21192103951581

# %%
print(ytestT.size())
print(finalpred.size())
#dif1 = ((ytestT[0,0,0]-finalpred[0,0])/320)**2+((ytestT[0,1,0]-finalpred[0,1])/180)**2
#dif2 = ((ytestT[:,0,1]-finalpred.data[:,2])/320)**2+((ytestT[:,1,1]-finalpred.data[:,3])/180)**2
#print(dif1)
#print(dif2)

angle_pred=torch.atan((finalpred.data[:,3]-finalpred.data[:,1])/(finalpred.data[:,2]-finalpred.data[:,0]))
#print(ang*(180/np.pi))
#ang1=ang
for i in range(0,angle_pred.size(0)):
    if angle_pred[i]<0:
        angle_pred[i]+=np.pi
        
#print(angle_pred)        
angle_diff=torch.abs(ytestT[:,0,2]-angle_pred[:])
mse_angle=torch.mean(torch.pow  (angle_diff,2)) 
abs_angle=torch.mean((angle_diff))
angle_diff*=180/np.pi
print (mse_angle*(180/np.pi))
print(abs_angle)

np.savetxt("pred_angle.csv", angle_diff.numpy(), delimiter=",")
# Out:
# torch.Size([1560, 2, 3])
# torch.Size([1560, 4])
# 51.838359108884944
# 0.7197120178968478

# %%
#dif = torch.abs(finalpred.data[:,0]-ytestT[:,0])

    # diff1 = ((tar[:,0]-inp[:,0])/320)**2+((tar[:,1]-inp[:,1])/180)**2
     #diff2 = ((tar[:,2]-inp[:,2])/320)**2+((tar[:,3]-inp[:,3])/180)**2
      #  diff=diff1+diff2
       # loss = torch.mean(diff)

        
        
        
#dif1 = ((ytestT[:,0,0]-finalpred.data[:,0])/320)**2+((ytestT[:,1,0]-finalpred.data[:,1])/180)**2
#dif2 = ((ytestT[:,0,1]-finalpred.data[:,2])/320)**2+((ytestT[:,1,1]-finalpred.data[:,3])/180)**2
#dif=dif1+dif2
       
         
dif1 = ((ytestT[:,0,0]-finalpred.data[:,0]))**2+((ytestT[:,1,0]-finalpred.data[:,1]))**2
dif2 = ((ytestT[:,0,1]-finalpred.data[:,2]))**2+((ytestT[:,1,1]-finalpred.data[:,3]))**2
dif=dif1+dif2
        
        
        






print(dif.size())
np.savetxt("diff.csv", dif.numpy(), delimiter=",")
MSEloss = torch.mean(torch.pow(dif,2))
ABSloss = torch.mean(dif)
print("MSEloss=="+str(MSEloss),"ABSloss=="+str(ABSloss))
# Out:
# torch.Size([1560])
# MSEloss==208950678.31407315 ABSloss==11412.042116854742

# %%
print(finalpred.data[0,0], finalpred.data[0,1], finalpred.data[0,2], finalpred.data[0,3])
print(ytestT[0,0,0],ytestT[0,1,0],ytestT[0,0,1],ytestT[0,1,1])
# Out:
# 126.92657470703125 178.7459259033203 188.37425231933594 107.12451171875
# 157.1005859375 179.46665954589844 157.1005859375 79.46666717529297

# %%
n=887

print(finalpred.data[n,0]*(180/np.pi))
print(ytestT[n,0]*(180/np.pi))
print(ytestT[n,0]*(180/np.pi)-finalpred.data[n,0]*(180/np.pi))
# Out:
# 84.39787451704454
# 43.8015182038607
# -40.59635631318384

# %%
ABSloss*(180/np.pi)
# Out:
# 18.336335510683693

# %%
#print(ytestT[:,0]*(180/np.pi))
print(ytestT[:,0]*(180/np.pi))
a = ytestT[:,0]*(180/np.pi)
print(a.size())
np.savetxt("test.csv", a.numpy(), delimiter=",")

# %%
#a = np.asarray([ [1,2,3], [4,5,6], [7,8,9] ])
#np.savetxt("foo.csv", a, delimiter=",")

# %%
#print(finalpred.data[:,0]*(180/np.pi))
print(finalpred.data[:,0]*(180/np.pi))
b = finalpred.data[:,0]*(180/np.pi)
c=torch.abs(ytestT[:,0]*(180/np.pi)- finalpred.data[:,0]*(180/np.pi))
np.savetxt("pred.csv", b.numpy(), delimiter=",")

np.savetxt("diff.csv", c.numpy(), delimiter=",")

# %%
finalpred.data[1,0]

# %%
import scipy
from scipy.misc import imresize, imread, imshow
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['image.interpolation'] = 'none'
# %matplotlib inline

fig = plt.figure()
fig.set_figheight(9)
fig.set_figwidth(9)
import cv2

test = cv2.imread("./Test_Net_image/4.JPG")
print(test.shape)
test = imresize(test,(180,320,3))
#imshow(test)
test = test.transpose(2,0,1)
test = np.reshape(test,(1,3,180,320))
test = test.astype(np.float32)
testPT = torch.from_numpy(test).float()
testPT = batch_rgb_to_bgr(testPT)
testPT = torch.div(testPT,255.0)
mn = [0.406,0.456,0.485]
sd = [0.225,0.224,0.229]
norm = Normalize(mn,sd)
testPT = norm(testPT)
'''
ind = 2000
testPT = xtestT[ind]
print("Actual angle==="+str(ytestT[ind,0]*(180/np.pi)), ytestT[ind,0])
testPT = testPT.view(1,3,180,320)
#'''
test_pred = net.forward(Variable(testPT, volatile=True).cuda())
print("Angle==="+str(test_pred.data[0,0]*(180/np.pi)), test_pred.data[0,0])
testx = testPT.numpy()
testx = np.reshape(testx,(3,180,320))
testx = testx.transpose(1,2,0)
testx = imresize(testx,(180,320,3))
#imshow(testx)
scipy.misc.imsave('test.png', testx)
a=fig.add_subplot(1,2,1)
imgplot = plt.imshow(testx)
a.set_title('Input')
a.axes.get_xaxis().set_visible(False)
a.axes.get_yaxis().set_visible(False)
